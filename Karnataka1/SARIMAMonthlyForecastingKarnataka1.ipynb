# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
# !pip install scikit-learn==0.24
# Out:
# Collecting scikit-learn==0.24
#   Downloading https://files.pythonhosted.org/packages/b1/ed/ab51a8da34d2b3f4524b21093081e7f9e2ddf1c9eac9f795dcf68ad0a57d/scikit_learn-0.24.0-cp37-cp37m-manylinux2010_x86_64.whl (22.3MB)
#      |████████████████████████████████| 22.3MB 44.3MB/s
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn==0.24) (1.0.1)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.7/dist-packages (from scikit-learn==0.24) (1.19.5)
# Requirement already satisfied: scipy>=0.19.1 in /usr/local/lib/python3.7/dist-packages (from scikit-learn==0.24) (1.4.1)
# Collecting threadpoolctl>=2.0.0
#   Downloading https://files.pythonhosted.org/packages/f7/12/ec3f2e203afa394a149911729357aa48affc59c20e2c1c8297a60f33f133/threadpoolctl-2.1.0-py3-none-any.whl
# Installing collected packages: threadpoolctl, scikit-learn
#   Found existing installation: scikit-learn 0.22.2.post1
#     Uninstalling scikit-learn-0.22.2.post1:
#       Successfully uninstalled scikit-learn-0.22.2.post1
# Successfully installed scikit-learn-0.24.0 threadpoolctl-2.1.0

# %%
# !pip install pmdarima==1.8.0
# Out:
# Collecting pmdarima==1.8.0
#   Downloading https://files.pythonhosted.org/packages/e4/a8/bdf15174e35d072e145d16388b1d3bc7605b752610170cb022a290411427/pmdarima-1.8.0-cp37-cp37m-manylinux1_x86_64.whl (1.5MB)
#      |████████████████████████████████| 1.5MB 6.2MB/s
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pmdarima==1.8.0) (1.19.5)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.7/dist-packages (from pmdarima==1.8.0) (1.1.5)
# Collecting statsmodels!=0.12.0,>=0.11
#   Downloading https://files.pythonhosted.org/packages/da/69/8eef30a6237c54f3c0b524140e2975f4b1eea3489b45eb3339574fc8acee/statsmodels-0.12.2-cp37-cp37m-manylinux1_x86_64.whl (9.5MB)
#      |████████████████████████████████| 9.5MB 22.5MB/s
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.7/dist-packages (from pmdarima==1.8.0) (0.24.0)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /usr/local/lib/python3.7/dist-packages (from pmdarima==1.8.0) (56.0.0)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.7/dist-packages (from pmdarima==1.8.0) (1.4.1)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from pmdarima==1.8.0) (1.24.3)
# Collecting Cython<0.29.18,>=0.29
#   Downloading https://files.pythonhosted.org/packages/dc/6c/198da24bf0a1d5b5ee6119e891c5300bb1b0b8904832fac9ff62d4e381c9/Cython-0.29.17-cp37-cp37m-manylinux1_x86_64.whl (2.1MB)
#      |████████████████████████████████| 2.1MB 34.7MB/s
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from pmdarima==1.8.0) (1.0.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19->pmdarima==1.8.0) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19->pmdarima==1.8.0) (2018.9)
# Requirement already satisfied: patsy>=0.5 in /usr/local/lib/python3.7/dist-packages (from statsmodels!=0.12.0,>=0.11->pmdarima==1.8.0) (0.5.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.22->pmdarima==1.8.0) (2.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.19->pmdarima==1.8.0) (1.15.0)
# Installing collected packages: statsmodels, Cython, pmdarima
#   Found existing installation: statsmodels 0.10.2
#     Uninstalling statsmodels-0.10.2:
#       Successfully uninstalled statsmodels-0.10.2
#   Found existing installation: Cython 0.29.22
#     Uninstalling Cython-0.29.22:
#       Successfully uninstalled Cython-0.29.22
# Successfully installed Cython-0.29.17 pmdarima-1.8.0 statsmodels-0.12.2

# %%
filename = "/content/gdrive/My Drive/BITS/4-2/ASM_sop/Karnataka1/dataset.csv"
# The data of all the files from year 2000-2014 of AP have been combined and put into one file called Dataset
df = pd.read_csv(filename)
df=df.iloc[:,:17]
df
# Out:
#         Year  Month  Day  Hour  ...  DNI Perez  Fill Flag  GHI  GHI Perez
# 0       2000      1    1     0  ...          0          0    0          0
# 1       2000      1    1     1  ...          0          0    0          0
# 2       2000      1    1     2  ...        297          0  109        110
# 3       2000      1    1     3  ...        657          0  335        343
# 4       2000      1    1     4  ...        790          0  549        554
# ...      ...    ...  ...   ...  ...        ...        ...  ...        ...
# 131395  2014     12   31    19  ...          0          0    0          0
# 131396  2014     12   31    20  ...          0          0    0          0
# 131397  2014     12   31    21  ...          0          0    0          0
# 131398  2014     12   31    22  ...          0          0    0          0
# 131399  2014     12   31    23  ...          0          0    0          0
#
# [131400 rows x 17 columns]

# %%
df['Date']=df['Year'].astype(str) + df['Month'].astype(str).str.zfill(2) + df['Day'].astype(str).str.zfill(2) + df['Hour'].astype(str).str.zfill(2)+df['Minute'].astype(str)

df['Date'] = pd.to_datetime(df['Date'], format='%Y%m%d%H%M')
df.head(10)
# Out:
#    Year  Month  Day  Hour  ...  Fill Flag  GHI  GHI Perez                Date
# 0  2000      1    1     0  ...          0    0          0 2000-01-01 00:00:00
# 1  2000      1    1     1  ...          0    0          0 2000-01-01 01:00:00
# 2  2000      1    1     2  ...          0  109        110 2000-01-01 02:00:00
# 3  2000      1    1     3  ...          0  335        343 2000-01-01 03:00:00
# 4  2000      1    1     4  ...          0  549        554 2000-01-01 04:00:00
# 5  2000      1    1     5  ...          0  718        721 2000-01-01 05:00:00
# 6  2000      1    1     6  ...          0  822        825 2000-01-01 06:00:00
# 7  2000      1    1     7  ...          0  798        798 2000-01-01 07:00:00
# 8  2000      1    1     8  ...          0  777        777 2000-01-01 08:00:00
# 9  2000      1    1     9  ...          0  685        693 2000-01-01 09:00:00
#
# [10 rows x 18 columns]

# %%
X=df[['Date','GHI']]
X.set_index('Date',inplace=True)
print(X.shape)
# Out:
# (131400, 1)

# %%
#y=X['GHI']
X=X.between_time('08:00','17:00',include_start=True,include_end=True)
X=X.reset_index()
y=X.resample('M',on='Date').mean()
y=y.dropna()
#y=np.log(y+1)
del X
del df
y.plot(figsize=[16,8],title='Time Series Plot')

# %%
y[:'2012'].plot(figsize=[15,7],title='Time Series Plot')

# %%
X_train=y[:'2011']
X_test=y['2012':]

# %%
np.any(np.isnan(X_test))
# Out:
# False

# %%
X_train.plot(figsize=(15,7))

# %%
from pmdarima.arima import auto_arima
stepwise_model = auto_arima(X_train, start_p=0, start_q=0,max_p=1,max_d=1,max_q=1, d=1, m=12,trace=True,error_action='ignore',suppress_warnings=True,stepwise=True)
stepwise_model.summary()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(1,0,1)[12] intercept   : AIC=1219.516, Time=0.47 sec
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=1342.815, Time=0.02 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=1241.601, Time=0.30 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=1293.368, Time=0.18 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=1340.846, Time=0.01 sec
#  ARIMA(0,1,0)(0,0,1)[12] intercept   : AIC=1292.206, Time=0.22 sec
#  ARIMA(0,1,0)(1,0,0)[12] intercept   : AIC=1249.131, Time=0.13 sec
#  ARIMA(0,1,0)(2,0,1)[12] intercept   : AIC=1221.282, Time=0.84 sec
#  ARIMA(0,1,0)(1,0,2)[12] intercept   : AIC=1221.222, Time=0.86 sec
#  ARIMA(0,1,0)(0,0,2)[12] intercept   : AIC=1270.560, Time=0.49 sec
#  ARIMA(0,1,0)(2,0,0)[12] intercept   : AIC=1238.321, Time=0.46 sec
#  ARIMA(0,1,0)(2,0,2)[12] intercept   : AIC=inf, Time=2.09 sec
#  ARIMA(1,1,0)(1,0,1)[12] intercept   : AIC=1202.123, Time=0.59 sec
#  ARIMA(1,1,0)(0,0,1)[12] intercept   : AIC=1293.511, Time=0.28 sec
#  ARIMA(1,1,0)(2,0,1)[12] intercept   : AIC=inf, Time=1.66 sec
#  ARIMA(1,1,0)(1,0,2)[12] intercept   : AIC=inf, Time=2.30 sec
#  ARIMA(1,1,0)(0,0,0)[12] intercept   : AIC=1332.932, Time=0.08 sec
#  ARIMA(1,1,0)(0,0,2)[12] intercept   : AIC=1272.405, Time=0.60 sec
#  ARIMA(1,1,0)(2,0,0)[12] intercept   : AIC=inf, Time=0.77 sec
#  ARIMA(1,1,0)(2,0,2)[12] intercept   : AIC=1205.391, Time=2.31 sec
#  ARIMA(1,1,1)(1,0,1)[12] intercept   : AIC=1166.806, Time=1.95 sec
#  ARIMA(1,1,1)(0,0,1)[12] intercept   : AIC=1294.973, Time=0.51 sec
#  ARIMA(1,1,1)(1,0,0)[12] intercept   : AIC=inf, Time=1.08 sec
#  ARIMA(1,1,1)(2,0,1)[12] intercept   : AIC=1169.872, Time=2.97 sec
#  ARIMA(1,1,1)(1,0,2)[12] intercept   : AIC=1169.818, Time=2.50 sec
#  ARIMA(1,1,1)(0,0,0)[12] intercept   : AIC=1333.408, Time=0.15 sec
#  ARIMA(1,1,1)(0,0,2)[12] intercept   : AIC=inf, Time=2.20 sec
#  ARIMA(1,1,1)(2,0,0)[12] intercept   : AIC=inf, Time=1.94 sec
#  ARIMA(1,1,1)(2,0,2)[12] intercept   : AIC=inf, Time=4.39 sec
#  ARIMA(0,1,1)(1,0,1)[12] intercept   : AIC=inf, Time=1.48 sec
#  ARIMA(1,1,1)(1,0,1)[12]             : AIC=inf, Time=3.43 sec
#
# Best model:  ARIMA(1,1,1)(1,0,1)[12] intercept
# Total fit time: 37.336 seconds
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                                  y   No. Observations:                  144
# Model:             SARIMAX(1, 1, 1)x(1, 0, 1, 12)   Log Likelihood                -577.403
# Date:                            Sun, 02 May 2021   AIC                           1166.806
# Time:                                    18:00:43   BIC                           1184.583
# Sample:                                         0   HQIC                          1174.029
#                                             - 144
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept  -1.719e-05      0.000     -0.052      0.958      -0.001       0.001
# ar.L1          0.2854      0.078      3.649      0.000       0.132       0.439
# ma.L1         -0.9871      0.058    -17.000      0.000      -1.101      -0.873
# ar.S.L12       0.9971      0.004    278.176      0.000       0.990       1.004
# ma.S.L12      -0.8307      0.097     -8.522      0.000      -1.022      -0.640
# sigma2       143.3608     12.448     11.517      0.000     118.963     167.759
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                 2.42
# Prob(Q):                              0.99   Prob(JB):                         0.30
# Heteroskedasticity (H):               1.37   Skew:                            -0.22
# Prob(H) (two-sided):                  0.28   Kurtosis:                         3.46
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
stepwise_model.fit(X_train)
#print(stepwise_model.summary())
# Out:
# ARIMA(order=(1, 1, 1), scoring_args={}, seasonal_order=(1, 0, 1, 12),
#       suppress_warnings=True)

# %%
X_test.shape
# Out:
# (36, 1)

# %%
pred=stepwise_model.predict(n_periods=36)

# %%
pred = pd.DataFrame(pred,index = X_test.index,columns=['Prediction'])
pd.concat([X_test,pred],axis=1).plot(figsize=(20,10))

# %%
df1 = pd.read_csv('/content/gdrive/My Drive/BITS/4-2/ASM_sop/Code/Karnataka1/MLP_monthly.csv')
#df2 = pd.read_csv('/content/gdrive/My Drive/BITS/4-2/ASM_sop/Code/AndhraPradesh1/LSTM_monthly.csv')

plt.figure(figsize = (20,10))
plt.plot(X_test.index,df1['GHI'],color='orange',label='MLP model')
#plt.plot(df1['Date'],df2['GHI'], color= 'blue', label= 'LSTM model')
plt.plot(X_test.index,pred , color= 'green', label= 'SARIMA model') 
plt.plot(X_test.index,X_test , color= 'red', label= 'Actual GHI') 
plt.xlabel('Date')
plt.ylabel('GHI')
plt.legend()
plt.show()

# %%
Fdates= pd.date_range('2012-01-01','2022-01-01' , freq='1M')
pred1=stepwise_model.predict(n_periods=120)
plt.figure(figsize = (20,10))
plt.plot(X_test.index,X_test , color= 'red', label= 'Actual GHI') 
plt.plot(Fdates,pred1 , color= 'green', label= 'SARIMA model') 
plt.xlabel('Date')
plt.ylabel('GHI Value')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_absolute_percentage_error
mean_absolute_percentage_error(X_test,pred)
# Out:
# 0.028324832867458002

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(X_test, pred, squared=False)
# Out:
# 8.57399393119378
